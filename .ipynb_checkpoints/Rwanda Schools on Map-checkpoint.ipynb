# %% [markdown]
# ## Schools Distribution on Map, Rwanda

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import geopandas as gpd
from shapely.geometry import LineString, MultiLineString
import pandas as pd
import numpy as np

# %%
level = 1
gdf = gpd.read_file(f"gadm36_RWA_shp/gadm36_RWA_{level}.shp", encoding='utf-8')
gdf.head()
# Out:
#   GID_0  NAME_0    GID_1            NAME_1  \
# 0   RWA  Rwanda  RWA.1_1      Amajyaruguru
# 1   RWA  Rwanda  RWA.2_1         Amajyepfo
# 2   RWA  Rwanda  RWA.3_1     Iburasirazuba
# 3   RWA  Rwanda  RWA.4_1    Iburengerazuba
# 4   RWA  Rwanda  RWA.5_1  Umujyi wa Kigali
#
#                                            VARNAME_1 NL_NAME_1    TYPE_1  \
# 0                 Northern Province|Province du Nord      None  Province
# 1                  Southern Province|Province du Sud      None  Province
# 2                 Eastern Province|Province de l'Est      None  Province
# 3  Western Province|Province de l'Ouestern Provin...      None  Province
# 4                        Kigali City|Ville de Kigali      None  Province
#
#   ENGTYPE_1 CC_1 HASC_1                                           geometry
# 0  Province    4  RW.NO  POLYGON ((30.23736191 -1.84603322, 30.23693466...
# 1  Province    2  RW.SU  POLYGON ((29.83833694 -2.77412415, 29.837883 -...
# 2  Province    5  RW.ES  POLYGON ((30.77458 -2.38958669, 30.77396011 -2...
# 3  Province    3  RW.OU  (POLYGON ((29.37956619 -1.5084672, 29.37983513...
# 4  Province    1  RW.KV  POLYGON ((30.220047 -2.0725317, 30.21941566 -2...

# %%
geo_names = list(gdf[f'NAME_{level}'])
geo_names
# Out:
# ['Amajyaruguru',
#  'Amajyepfo',
#  'Iburasirazuba',
#  'Iburengerazuba',
#  'Umujyi wa Kigali']

# %%
gdf['geometry'][0]

# %%
gdf['geometry'][1]

# %%
gdf['geometry'][2]

# %%
gdf['geometry'][3]

# %%
gdf['geometry'][4]
